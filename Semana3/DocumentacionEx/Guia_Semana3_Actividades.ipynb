# %% [markdown]
# # Semana 3: Guía de Actividades - Python para Ciencia de Datos
#
# ## Objetivos de Aprendizaje
#
# Esta guía te preparará para completar los ejercicios y actividades de la Semana 3. Aquí aprenderás los conceptos fundamentales que necesitas dominar antes de realizar las actividades prácticas.
#
# ### Temas Cubiertos:
# - **T6**: Python para ciencia de datos
# - **T7**: El proceso de ciencia de datos
# - **T8**: Análisis exploratorio de datos en Python
#
# ---
#
# ## 1. Fundamentos de Python
#
# Python es el lenguaje principal para el análisis de datos. En esta sección repasaremos los conceptos básicos que usarás constantemente.

# %% [markdown]
# ### 1.1 Variables y Tipos de Datos
#
# Las **variables** son contenedores que almacenan valores. En Python temos diferentes **tipos de datos**:
#
# | Tipo | Descripción | Ejemplo |
# |------|-------------|--------|
# | `int` | Números enteros | `edad = 25` |
# | `float` | Números decimales | `precio = 19.99` |
# | `str` | Cadenas de texto | `nombre = "Ana"` |
# | `bool` | Valores booleanos | `es_estudiante = True` |
# | `list` | Listas ordenadas | `numeros = [1, 2, 3]` |
# | `dict` | Diccionarios | `datos = {"nombre": "Ana"}` |

# %%
# Ejemplo práctico: Creando variables de diferentes tipos

# Variables de diferentes tipos
edad = 25                    # int
altura = 1.75                # float
nombre = "María"             # str
es_estudiante = True        # bool
calificaciones = [8.5, 9.0, 7.8, 8.2]  # list
informacion = {"nombre": nombre, "edad": edad}  # dict

# Mostrando los valores
print(f"Nombre: {nombre}")
print(f"Edad: {edad} años")
print(f"Altura: {altura} m")
print(f"Es estudiante: {es_estudiante}")
print(f"Calificaciones: {calificaciones}")
print(f"Información: {informacion}")

# %% [markdown]
# ### 1.2 Conversión de Tipos
#
# A veces necesitamos **convertir** un tipo de dato a otro. Esto se llama **casting**.

# %%
# Ejemplo práctico: Conversión de tipos

# Convertir string a int
numero_str = "42"
numero_int = int(numero_str)
print(f"'{numero_str}' (str) → {numero_int} (int)")

# Convertir float a int (trunca la parte decimal)
pi = 3.14159
pi_entero = int(pi)
print(f"{pi} (float) → {pi_entero} (int)")

# Convertir int a float
numero = 5
numero_float = float(numero)
print(f"{numero} (int) → {numero_float} (float)")

# Convertir número a string
año = 2024
año_str = str(año)
print(f"{año} (int) → '{año_str}' (str)")

# %% [markdown]
# ### 1.3 Estructuras de Control: Condicionales
#
# Los **condicionales** nos permiten ejecutar código basándonos en condiciones específicas.

# %%
# Ejemplo práctico: Condicionales if-elif-else

def classify_number(n):
    """Clasifica un número como positivo, negativo o cero"""
    if n > 0:
        return "positivo"
    elif n < 0:
        return "negativo"
    else:
        return "cero"

# Probando la función
test_numbers = [-5, 0, 10, -3, 7]

for num in test_numbers:
    classification = classify_number(num)
    print(f"El número {num} es {classification}")

# %% [markdown]
# ### 1.4 Funciones
#
# Las **funciones** son bloques de código reutilizables que realizan una tarea específica. Usar funciones nos ayuda a escribir código más limpio y modular.

# %%
# Ejemplo práctico: Funciones útiles para ciencia de datos

import math

# Función 1: Área de un círculo
def area_circunferencia(radio):
    """Calcula el área de un círculo dado su radio"""
    return math.pi * radio ** 2

# Función 2: Convertir Celsius a Fahrenheit
def celsius_a_fahrenheit(celsius):
    """Convierte grados Celsius a Fahrenheit"""
    return (celsius * 9/5) + 32

# Función 3: Calcular el promedio de una lista
def calcular_promedio(lista):
    """Calcula el promedio de una lista de números"""
    if len(lista) == 0:
        return 0
    return sum(lista) / len(lista)

# Función 4: Encontrar valor máximo y mínimo
def max_min(lista):
    """Encuentra el valor máximo y mínimo de una lista"""
    return max(lista), min(lista)

# Probando las funciones
print(f"Área de un círculo con radio 5: {area_circunferencia(5):.2f}")
print(f"25°C en Fahrenheit: {celsius_a_fahrenheit(25):.2f}°F")
print(f"Promedio de [10, 20, 30, 40, 50]: {calcular_promedio([10, 20, 30, 40, 50])}")
print(f"Máximo y mínimo de [3, 1, 4, 1, 5]: {max_min([3, 1, 4, 1, 5])}")

# %% [markdown]
# ---
#
# ## 2. NumPy: Computación Numérica
#
# **NumPy** es la librería fundamental para computación numérica en Python. Proporciona soporte para arrays multidimensionales y funciones matemáticas de alto rendimiento.

# %%
import numpy as np

# Creando arrays simples
arr1 = np.array([1, 2, 3, 4, 5])
arr2 = np.array([5, 4, 3, 2, 1])

print("Array 1:", arr1)
print("Array 2:", arr2)

# %% [markdown]
# ### 2.1 Operaciones Básicas con Arrays

# %%
import numpy as np

arr1 = np.array([1, 2, 3, 4, 5])
arr2 = np.array([5, 4, 3, 2, 1])

# 1. Sumar arrays elemento a elemento
suma = arr1 + arr2
print(f"arr1 + arr2 = {suma}")

# 2. Multiplicar por un escalar
multiplicado = arr1 * 3
print(f"arr1 * 3 = {multiplicado}")

# 3. Calcular media, mediana y desviación estándar
datos = np.array([10, 20, 30, 40, 50])
print(f"Media: {np.mean(datos)}")
print(f"Mediana: {np.median(datos)}")
print(f"Desviación estándar: {np.std(datos):.2f}")

# 4. Encontrar valores únicos
arr_con_duplicados = np.array([1, 2, 2, 3, 3, 3, 4])
unicos = np.unique(arr_con_duplicados)
print(f"Valores únicos en {arr_con_duplicados}: {unicos}")

# %% [markdown]
# ### 2.2 Álgebra con NumPy

# %%
import numpy as np

v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])

# 1. Producto punto (dot product)
producto_punto = np.dot(v1, v2)
print(f"Producto punto de {v1} y {v2}: {producto_punto}")

# 2. Producto cruz (cross product)
producto_cruz = np.cross(v1, v2)
print(f"Producto cruz de {v1} y {v2}: {producto_cruz}")

# 3. Magnitud de cada vector
magnitud_v1 = np.linalg.norm(v1)
magnitud_v2 = np.linalg.norm(v2)
print(f"|v1| = {magnitud_v1:.2f}")
print(f"|v2| = {magnitud_v2:.2f}")

# 4. Normalización de vectores
v1_normalizado = v1 / np.linalg.norm(v1)
v2_normalizado = v2 / np.linalg.norm(v2)
print(f"v1 normalizado: {v1_normalizado}")
print(f"v2 normalizado: {v2_normalizado}")

# %% [markdown]
# ---
#
# ## 3. Pandas: Manipulación de Datos
#
# **Pandas** es la librería principal para manipulación y análisis de datos. Proporciona estructuras de datos flexibles para manejar datos tabulares.

# %%
import pandas as pd

# Crear un DataFrame con datos de estudiantes
data = {
    'nombre': ['Ana', 'Luis', 'María', 'Carlos', 'Sofía'],
    'edad': [20, 22, 19, 21, 23],
    'carrera': ['Ing', 'Ing', 'Lic', 'Ing', 'Lic'],
    'promedio': [8.5, 9.0, 7.8, 8.2, 9.5]
}

df = pd.DataFrame(data)
print("DataFrame de estudiantes:")
df

# %% [markdown]
# ### 3.1 Operaciones Básicas con DataFrames

# %%
import pandas as pd

data = {
    'nombre': ['Ana', 'Luis', 'María', 'Carlos', 'Sofía'],
    'edad': [20, 22, 19, 21, 23],
    'carrera': ['Ing', 'Ing', 'Lic', 'Ing', 'Lic'],
    'promedio': [8.5, 9.0, 7.8, 8.2, 9.5]
}

df = pd.DataFrame(data)

# 1. Seleccionar columna 'nombre'
nombres = df['nombre']
print("Nombres:", nombres.tolist())

# 2. Filtrar estudiantes con promedio > 8.5
destacados = df[df['promedio'] > 8.5]
print("\nEstudiantes con promedio > 8.5:")
print(destacados)

# 3. Ordenar por edad
ordenado = df.sort_values('edad')
print("\nEstudiantes ordenados por edad:")
print(ordenado)

# 4. Agregar columna 'aprobado' (promedio >= 7)
df['aprobado'] = df['promedio'] >= 7
print("\nDataFrame con columna 'aprobado':")
print(df)

# %%
import pandas as pd

data = {
    'nombre': ['Ana', 'Luis', 'María', 'Carlos', 'Sofía'],
    'edad': [20, 22, 19, 21, 23],
    'carrera': ['Ing', 'Ing', 'Lic', 'Ing', 'Lic'],
    'promedio': [8.5, 9.0, 7.8, 8.2, 9.5]
}

df = pd.DataFrame(data)

# 5. Group by carrera y promediar
promedio_por_carrera = df.groupby('carrera')['promedio'].mean()
print("Promedio por carrera:")
print(promedio_por_carrera)

# %% [markdown]
# ### 3.2 Manipulación Avanzada de Datos

# %%
import pandas as pd
import numpy as np

data = {
    'nombre': ['Ana', 'Luis', 'María', 'Carlos', 'Sofía'],
    'edad': [20, 22, 19, 21, 23],
    'carrera': ['Ing', 'Ing', 'Lic', 'Ing', 'Lic'],
    'promedio': [8.5, 9.0, 7.8, 8.2, 9.5]
}

df = pd.DataFrame(data)

# 1. Manejar valores faltantes
# Agregar un valor nulo
df_con_nulos = df.copy()
df_con_nulos.loc[2, 'promedio'] = np.nan
print("DataFrame con valor nulo:")
print(df_con_nulos)

# Llenar valores nulos con el promedio
df_lleno = df_con_nulos.fillna(df_con_nulos['promedio'].mean())
print("\nDataFrame con valores nulos llenados:")
print(df_lleno)

# 2. Usar loc para selección por etiqueta
print("\nUsando loc (fila con etiqueta '2'):")
print(df.loc[2])

# 3. Usar iloc para selección por índice
print("\nUsando iloc (primeras 3 filas):")
print(df.iloc[:3])

# %% [markdown]
# ---
#
# ## 4. Visualización con Matplotlib
#
# **Matplotlib** es la librería principal para crear visualizaciones estáticas, animadas e interactivas en Python.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configurar el estilo
plt.style.use('seaborn-v0_8-whitegrid')

x = np.linspace(0, 10, 100)
y = np.sin(x)

# Crear gráfica de línea
plt.figure(figsize=(10, 4))
plt.plot(x, y, color='blue', linewidth=2)
plt.title('Función Seno', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('sin(x)', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4.1 Diferentes Tipos de Gráficas

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12, 8))

# 1. Gráfico de dispersión
plt.subplot(2, 2, 1)
x_disp = np.random.randn(50)
y_disp = np.random.randn(50)
plt.scatter(x_disp, y_disp, alpha=0.6, color='purple')
plt.title('Gráfico de Dispersión')
plt.xlabel('X')
plt.ylabel('Y')

# 2. Histograma
plt.subplot(2, 2, 2)
datos_hist = np.random.randn(1000)
plt.hist(datos_hist, bins=30, color='steelblue', edgecolor='black')
plt.title('Histograma')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')

# 3. Gráfico de barras
plt.subplot(2, 2, 3)
categorias = ['Ing', 'Lic', 'Doc', 'Arq']
valores = [45, 30, 15, 10]
plt.bar(categorias, valores, color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728'])
plt.title('Gráfico de Barras')
plt.xlabel('Carrera')
plt.ylabel('Cantidad')

# 4. Boxplot
plt.subplot(2, 2, 4)
datos_box = [np.random.normal(0, 1, 100),
            np.random.normal(0, 1.5, 100),
            np.random.normal(0, 2, 100)]
plt.boxplot(datos_box, labels=['Grupo A', 'Grupo B', 'Grupo C'])
plt.title('Boxplot')
plt.ylabel('Valor')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 5. Estadística Descriptiva
#
# La **estadística descriptiva** nos permite resumir y describir las características de un conjunto de datos.

# %% [markdown]
# ### 5.1 Medidas de Tendencia Central

# %%
import numpy as np
from collections import Counter

def calcular_estadisticas(datos):
    """Calcula media, mediana y moda"""
    # Media
    media = sum(datos) / len(datos)
    
    # Mediana (ordenando y buscando el centro)
    datos_ordenados = sorted(datos)
    n = len(datos_ordenados)
    if n % 2 == 0:
        mediana = (datos_ordenados[n//2 - 1] + datos_ordenados[n//2]) / 2
    else:
        mediana = datos_ordenados[n//2]
    
    # Moda
    conteo = Counter(datos)
    max_freq = max(conteo.values())
    moda = [k for k, v in conteo.items() if v == max_freq]
    
    return media, mediana, moda

# Ejemplos
datos1 = [5, 3, 8, 3, 7]
datos2 = [10, 20, 30, 40]
datos3 = [1, 2, 2, 3, 3, 3, 4]

print("Datos 1:", datos1)
media, mediana, moda = calcular_estadisticas(datos1)
print(f"  Media: {media}, Mediana: {mediana}, Moda: {moda}")

print("\nDatos 2:", datos2)
media, mediana, moda = calcular_estadisticas(datos2)
print(f"  Media: {media}, Mediana: {mediana}, Moda: {moda}")

print("\nDatos 3:", datos3)
media, mediana, moda = calcular_estadisticas(datos3)
print(f"  Media: {media}, Mediana: {mediana}, Moda: {moda}")

# %% [markdown]
# ### 5.2 Medidas de Dispersión

# %%
import numpy as np
import math

def calcular_dispersion(datos):
    """Calcula rango, varianza y desviación estándar"""
    # Rango
    rango = max(datos) - min(datos)
    
    # Varianza
    media = sum(datos) / len(datos)
    varianza = sum((x - media) ** 2 for x in datos) / len(datos)
    
    # Desviación estándar
    desv_est = math.sqrt(varianza)
    
    return rango, varianza, desv_est

# Ejemplos
datos1 = [2, 4, 4, 4, 5, 5, 7, 9]
datos2 = [1, 3, 5, 7, 9]

print("Datos 1:", datos1)
rango, varianza, desv_est = calcular_dispersion(datos1)
print(f"  Rango: {rango}, Varianza: {varianza:.2f}, Desviación Estándar: {desv_est:.2f}")

print("\nDatos 2:", datos2)
rango, varianza, desv_est = calcular_dispersion(datos2)
print(f"  Rango: {rango}, Varianza: {varianza:.2f}, Desviación Estándar: {desv_est:.2f}")

# %% [markdown]
# ---
#
# ## 6. El Proceso de Ciencia de Datos: CRISP-DM
#
# **CRISP-DM** (Cross-Industry Standard Process for Data Mining) es el método estándar más utilizado para proyectos de ciencia de datos. Consta de 6 fases:

# %% [markdown]
# ### Las 6 Fases de CRISP-DM
#
# | Fase | Descripción | Actividades |
# |------|-------------|-------------|
# | **1. Business Understanding** (Entendimiento del Negocio) | Definir objetivos del proyecto | Identificar preguntas de negocio, definir KPIs |
# | **2. Data Understanding** (Entendimiento de Datos) | Explorar los datos disponibles | Cargar datos, validar calidad, análisis inicial |
# | **3. Data Preparation** (Preparación de Datos) | Limpiar y transformar datos | Manejar valores nulos, normalizar, feature engineering |
# | **4. Modeling** (Modelado) | Construir modelos predictivos | Seleccionar algoritmos, entrenar modelos |
# | **5. Evaluation** (Evaluación) | Evaluar resultados | Métricas de evaluación, validación |
# | **6. Deployment** (Despliegue) | Implementar solución | Deploy, monitoreo, mantenimiento |

# %% [markdown]
# ### Aplicando CRISP-DM en la Semana 3
#
# En esta semana nos centraremos principalmente en las fases 1, 2 y 3:
#
# 1. **Business Understanding**: Definir las preguntas que queremos responder con nuestro dataset
# 2. **Data Understanding**: Explorar y entender los datos disponibles
# 3. **Data Preparation**: Limpiar y preparar los datos para el análisis
#
# Las actividades propuestas te guiarán a través de estas fases.

# %% [markdown]
# ---
#
# ## 7. Análisis Exploratorio de Datos (EDA)
#
# El **Análisis Exploratorio de Datos (EDA)** es el proceso de investigar un dataset para descubrir patrones, detectar anomalías y verificar suposiciones.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Usar el dataset iris como ejemplo
df = sns.load_dataset('iris')

# 1. Mostrar las primeras filas
print("Primeras 10 filas del dataset Iris:")
df.head(10)

# %%
# 2. Información del dataset
print("Información del dataset:")
df.info()

# %%
# 3. Estadísticas descriptivas
print("Estadísticas descriptivas:")
df.describe()

# %%
# 4. Matriz de correlación
plt.figure(figsize=(8, 6))
numericas = df.select_dtypes(include=['float64'])
sns.heatmap(numericas.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlación')
plt.show()

# %%
# 5. Distribución por especie
plt.figure(figsize=(6, 4))
df['species'].value_counts().plot(kind='bar', color=['#1f77b4', '#ff7f0e', '#2ca02c'])
plt.title('Distribución por Especie')
plt.xlabel('Especie')
plt.ylabel('Cantidad')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ---
#
# ## Resumen de Conceptos Clave
#
# En esta guía has aprendido:
#
# ### Programación Python
# - Variables y tipos de datos básicos
# - Condicionales y funciones
# - Conversión de tipos (casting)
#
# ### NumPy
# - Creación y operaciones con arrays
# - Álgebra vectorial (producto punto, producto cruz, normalización)
# - Funciones estadísticas básicas
#
# ### Pandas
# - Creación y manipulación de DataFrames
# - Selección, filtrado y ordenamiento
# - Group by y operaciones agregadas
# - Manejo de valores nulos
#
# ### Visualización
# - Gráficos de línea, dispersión, barras e histogramas
# - Personalización de gráficos
#
# ### Estadística
# - Medidas de tendencia central (media, mediana, moda)
# - Medidas de dispersión (rango, varianza, desviación estándar)
#
# ### Proceso de Ciencia de Datos
# - Fases CRISP-DM
# - Análisis Exploratorio de Datos (EDA)
#
# ---
#
# ## Próximos Pasos
#
# Ahora que has completado esta guía de conceptos, estás listo para:
#
# 1. Completar los **Ejercicios Complementarios** del archivo correspondiente
# 2. Realizar las **Actividades Prácticas** propuestas
# 3. Trabajar en el **Avance del Proyecto**
#
# ¡Éxito en tus actividades!
